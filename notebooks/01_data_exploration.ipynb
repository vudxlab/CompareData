# %% [markdown]
# # 01. Data Exploration
#
# Notebook này dùng để khám phá và làm quen với dữ liệu từ hai cảm biến gia tốc.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils.io import load_sensor_data
from src.utils.config import load_config, load_sensor_config

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Load Configuration

# %%
config = load_config('../configs/project.yaml')
sensor_a_config = load_sensor_config('sensor_a', '../configs/project.yaml')
sensor_b_config = load_sensor_config('sensor_b', '../configs/project.yaml')

print("Sensor A:", sensor_a_config['name'])
print("Sensor B:", sensor_b_config['name'])

# %% [markdown]
# ## 2. Load Data

# %%
# Load data from sensor A
# df_a = load_sensor_data('../data/raw/sensor_A/your_file.csv')

# Load data from sensor B
# df_b = load_sensor_data('../data/raw/sensor_B/your_file.csv')

# %% [markdown]
# ## 3. Data Overview

# %%
# df_a.info()
# df_a.describe()

# %% [markdown]
# ## 4. Quick Visualization

# %%
# fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)
# 
# for i, axis in enumerate(['x', 'y', 'z']):
#     axes[i].plot(df_a['time'], df_a[f'acc_{axis}'], label='Sensor A', alpha=0.7)
#     axes[i].plot(df_b['time'], df_b[f'acc_{axis}'], label='Sensor B', alpha=0.7)
#     axes[i].set_ylabel(f'{axis.upper()} (g)')
#     axes[i].legend()
#     axes[i].grid(True, alpha=0.3)
# 
# axes[-1].set_xlabel('Time (s)')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Next Steps
#
# - Tiền xử lý dữ liệu: `02_preprocessing.ipynb`
# - Phân tích chi tiết: `03_analysis.ipynb`
# - Trực quan hóa kết quả: `04_visualization.ipynb`
